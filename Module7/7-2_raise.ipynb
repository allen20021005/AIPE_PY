# %%
# 自訂例外處理
total = -100

if total < 0 :
    raise ValueError("金額不能小於0")

# %%
# 自訂型別錯誤(TypeError)的例外處理
file = "python.txt"

if file[-3:].lower() !="pdf":  #取他的副檔名
    raise TypeError("僅能上傳 PDF")

# %% [markdown]
# ##### 設計 raise 陳述
