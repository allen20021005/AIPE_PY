# %% [markdown]
# | | |
# |:---|:---|
# | | |

# %% [markdown]
# 算術運算子

# %%
a = 10 
b = 3

# a 的 2 次方
print(a**2)

# 相除取餘數
print(a%b)

# 相除取整數
print(a//b)

# 判斷奇偶數
print(a%2)
# Out:
# 100
# 1
# 3
# 0

# %% [markdown]
# 賦值運算子

# %%
a = 10
b = 3
b = b + a 
print(b)

# %% [markdown]
# 比較運算子 (用 if 判斷)

# %% [markdown]
# 邏輯運算子 and / or / not

# %% [markdown]
# 成員運算子 in / not in

# %% [markdown]
# 身分運算子 is / is not

# %% [markdown]
# 位元運算子
