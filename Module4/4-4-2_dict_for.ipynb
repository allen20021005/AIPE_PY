# %%
fruit_dict = {    
    'apple': {
        'price': 100,
        'quantity': 50,
        'color': ['green', 'red']
    },
    'orange': {
        'price': 50,
        'quantity': 30,
        'color': ['orange'] # 錯誤的寫法
    }
}
print(fruit_dict)
# Out:
# {'apple': {'price': 100, 'quantity': 50, 'color': ['green', 'red']}, 'orange': {'price': 50, 'quantity': 30, 'color': ['orange']}}

# %%
# 使用 for 迴圈讀取 dict 資料1 -->只回傳Key
for key in fruit_dict:
    print(key)
# Out:
# apple
# orange

# %%
# 使用 for 迴圈讀取 dict 資料2 -->dict.values() 只回傳 value
for value in fruit_dict.values():
    print(value)
# Out:
# {'price': 100, 'quantity': 50, 'color': ['greem', 'red']}
# {'price': 50, 'quantity': 30, 'color': 'orange'}

# %%
# 使用 for 迴圈讀取 dict 資料3 --> key , value 都回傳 dict.items()
for key, value in fruit_dict.items():
    print(key,value)
# Out:
# apple {'price': 100, 'quantity': 50, 'color': ['greem', 'red']}
# orange {'price': 50, 'quantity': 30, 'color': 'orange'}

# %%
for key, value in fruit_dict.items():
    for color in value["color"]:
        print(f"{key}有{color}")
# Out:
# apple有green
# apple有red
# orange有orange

# %%
for key, value in fruit_dict.items():
    result = ','.join(value['color'])
    print(f"{key} 有 {result}")
# Out:
# apple 有 green,red
# orange 有 orange

# %%
# 取得 dict 的 value
print(fruit_dict.get('kiwi'))
if fruit_dict.get('kiwi') == None:
    print(f'kiwi 不在 fruit_dict 裡面')
# Out:
# None
# kiwi 不在 fruit_dict 裡面

# %%
# 資料處理
fruit_color_list = [
    {'apple': 'red'}, 
    {'grape': 'purple'}, 
    {'kiwi': 'yellow'}, 
    {'apple': 'green'}, 
    {'kiwi': 'green'}, 
    {'grape': 'green'}]

# %%
# 將資料整理成 {'apple': ['red', 'green'], 'grape': ['purple', 'green'], 'kiwi': ['yellow', 'green']}

# %% [markdown]
# ##### `defaultdict(<type>)`

# %%
# 當訪問的鍵不存在時，可以自動創建鍵和預設值，而不是拋出KeyError。


# 以int型態的預設值 0 來初始化
